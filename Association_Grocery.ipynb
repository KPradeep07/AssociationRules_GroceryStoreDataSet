# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import seaborn as sns

# %%
df=pd.read_csv("GroceryStoreDataSet.csv")
df    # it considers first row as col. name, in this file col name is not given
# Out:
#                 MILK,BREAD,BISCUIT
# 0    BREAD,MILK,BISCUIT,CORNFLAKES
# 1              BREAD,TEA,BOURNVITA
# 2             JAM,MAGGI,BREAD,MILK
# 3                MAGGI,TEA,BISCUIT
# 4              BREAD,TEA,BOURNVITA
# 5             MAGGI,TEA,CORNFLAKES
# 6          MAGGI,BREAD,TEA,BISCUIT
# 7              JAM,MAGGI,BREAD,TEA
# 8                       BREAD,MILK
# 9   COFFEE,COCK,BISCUIT,CORNFLAKES
# 10  COFFEE,COCK,BISCUIT,CORNFLAKES
# 11          COFFEE,SUGER,BOURNVITA
# 12               BREAD,COFFEE,COCK
# 13             BREAD,SUGER,BISCUIT
# 14         COFFEE,SUGER,CORNFLAKES
# 15           BREAD,SUGER,BOURNVITA
# 16              BREAD,COFFEE,SUGER
# 17              BREAD,COFFEE,SUGER
# 18      TEA,MILK,COFFEE,CORNFLAKES

# %%
df1=pd.read_csv("GroceryStoreDataSet.csv", header=None) # Hence using header = none
df1.columns= ["List"]
df1
# Out:
#                               List
# 0               MILK,BREAD,BISCUIT
# 1    BREAD,MILK,BISCUIT,CORNFLAKES
# 2              BREAD,TEA,BOURNVITA
# 3             JAM,MAGGI,BREAD,MILK
# 4                MAGGI,TEA,BISCUIT
# 5              BREAD,TEA,BOURNVITA
# 6             MAGGI,TEA,CORNFLAKES
# 7          MAGGI,BREAD,TEA,BISCUIT
# 8              JAM,MAGGI,BREAD,TEA
# 9                       BREAD,MILK
# 10  COFFEE,COCK,BISCUIT,CORNFLAKES
# 11  COFFEE,COCK,BISCUIT,CORNFLAKES
# 12          COFFEE,SUGER,BOURNVITA
# 13               BREAD,COFFEE,COCK
# 14             BREAD,SUGER,BISCUIT
# 15         COFFEE,SUGER,CORNFLAKES
# 16           BREAD,SUGER,BOURNVITA
# 17              BREAD,COFFEE,SUGER
# 18              BREAD,COFFEE,SUGER
# 19      TEA,MILK,COFFEE,CORNFLAKES

# %%
sep_df= [x.split(",") for x in df1["List"]]
sep_df
# Out:
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COCK'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
encod=TransactionEncoder()
encod_df= encod.fit(sep_df).transform(sep_df)

# %%
encod_df
# Out:
# array([[ True, False,  True, False, False, False, False, False,  True,
#         False, False],
#        [ True, False,  True, False, False,  True, False, False,  True,
#         False, False],
#        [False,  True,  True, False, False, False, False, False, False,
#         False,  True],
#        [False, False,  True, False, False, False,  True,  True,  True,
#         False, False],
#        [ True, False, False, False, False, False, False,  True, False,
#         False,  True],
#        [False,  True,  True, False, False, False, False, False, False,
#         False,  True],
#        [False, False, False, False, False,  True, False,  True, False,
#         False,  True],
#        [ True, False,  True, False, False, False, False,  True, False,
#         False,  True],
#        [False, False,  True, False, False, False,  True,  True, False,
#         False,  True],
#        [False, False,  True, False, False, False, False, False,  True,
#         False, False],
# ...

# %%
encoded_df=pd.DataFrame(encod_df, columns= encod.columns_)
encoded_df
# Out:
#     BISCUIT  BOURNVITA  BREAD   COCK  COFFEE  ...    JAM  MAGGI   MILK  SUGER    TEA
# 0      True      False   True  False   False  ...  False  False   True  False  False
# 1      True      False   True  False   False  ...  False  False   True  False  False
# 2     False       True   True  False   False  ...  False  False  False  False   True
# 3     False      False   True  False   False  ...   True   True   True  False  False
# 4      True      False  False  False   False  ...  False   True  False  False   True
# 5     False       True   True  False   False  ...  False  False  False  False   True
# 6     False      False  False  False   False  ...  False   True  False  False   True
# 7      True      False   True  False   False  ...  False   True  False  False   True
# 8     False      False   True  False   False  ...   True   True  False  False   True
# 9     False      False   True  False   False  ...  False  False   True  False  False
# ...

# %%
freq_items= apriori(df= encoded_df, min_support=0.1, use_colnames=True)
freq_items.head(20)
# Out:
#     support               itemsets
# 0      0.35              (BISCUIT)
# 1      0.20            (BOURNVITA)
# 2      0.65                (BREAD)
# 3      0.15                 (COCK)
# 4      0.40               (COFFEE)
# 5      0.30           (CORNFLAKES)
# 6      0.10                  (JAM)
# 7      0.25                (MAGGI)
# 8      0.25                 (MILK)
# 9      0.30                (SUGER)
# 10     0.35                  (TEA)
# 11     0.20       (BREAD, BISCUIT)
# 12     0.10        (COCK, BISCUIT)
# 13     0.10      (BISCUIT, COFFEE)
# 14     0.15  (CORNFLAKES, BISCUIT)
# 15     0.10       (MAGGI, BISCUIT)
# 16     0.10        (MILK, BISCUIT)
# 17     0.10         (BISCUIT, TEA)
# 18     0.15     (BOURNVITA, BREAD)
# 19     0.10     (BOURNVITA, SUGER)

# %%
rule= association_rules(df=freq_items, metric="lift", min_threshold= 0.7)
rule
# Out:
#            antecedents                    consequents  ...  leverage  conviction
# 0              (BREAD)                      (BISCUIT)  ...   -0.0275    0.938889
# 1            (BISCUIT)                        (BREAD)  ...   -0.0275    0.816667
# 2               (COCK)                      (BISCUIT)  ...    0.0475    1.950000
# 3            (BISCUIT)                         (COCK)  ...    0.0475    1.190000
# 4            (BISCUIT)                       (COFFEE)  ...   -0.0400    0.840000
# ..                 ...                            ...  ...       ...         ...
# 115  (BISCUIT, COFFEE)             (COCK, CORNFLAKES)  ...    0.0900         inf
# 116             (COCK)  (CORNFLAKES, BISCUIT, COFFEE)  ...    0.0850    2.700000
# 117       (CORNFLAKES)        (COCK, BISCUIT, COFFEE)  ...    0.0700    1.350000
# 118          (BISCUIT)     (COCK, CORNFLAKES, COFFEE)  ...    0.0650    1.260000
# 119           (COFFEE)    (COCK, CORNFLAKES, BISCUIT)  ...    0.0600    1.200000
#
# ...

# %%
rule.sort_values("lift", ascending= False)
# Out:
#                        antecedents         consequents  ...  leverage  conviction
# 115              (BISCUIT, COFFEE)  (COCK, CORNFLAKES)  ...     0.090         inf
# 110             (COCK, CORNFLAKES)   (BISCUIT, COFFEE)  ...     0.090         inf
# 109  (CORNFLAKES, BISCUIT, COFFEE)              (COCK)  ...     0.085         inf
# 54               (BISCUIT, COFFEE)              (COCK)  ...     0.085         inf
# 55                          (COCK)   (BISCUIT, COFFEE)  ...     0.085    2.700000
# ..                             ...                 ...  ...       ...         ...
# 85                         (BREAD)     (SUGER, COFFEE)  ...    -0.030    0.945455
# 96                    (MAGGI, TEA)             (BREAD)  ...    -0.030    0.700000
# 84                 (SUGER, COFFEE)             (BREAD)  ...    -0.030    0.700000
# 5                         (COFFEE)           (BISCUIT)  ...    -0.040    0.866667
# ...

# %%
rule[["support", "confidence", "lift"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'support'}>,
#         <AxesSubplot:title={'center':'confidence'}>],
#        [<AxesSubplot:title={'center':'lift'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
rule[(rule.lift>=5) &  (rule.confidence>= 0.6)]
# Out:
#                        antecedents  ... conviction
# 54               (BISCUIT, COFFEE)  ...        inf
# 55                          (COCK)  ...        2.7
# 88                  (BREAD, MAGGI)  ...        2.7
# 93                           (JAM)  ...        inf
# 109  (CORNFLAKES, BISCUIT, COFFEE)  ...        inf
# 110             (COCK, CORNFLAKES)  ...        inf
# 111                (COCK, BISCUIT)  ...        inf
# 115              (BISCUIT, COFFEE)  ...        inf
# 116                         (COCK)  ...        2.7
#
# [9 rows x 9 columns]
